# %%
import pandas as pd

# %%
df = pd.read_csv("../dataset/wind_forecast.csv")

# %%
df.head()
# Out:
#          date  time_frame  hrs     u     v    ws      wd  farm
# 0  2009070100           1    1  2.34 -0.79  2.47  108.68     1
# 1  2009070100           1    2  2.18 -0.99  2.40  114.31     1
# 2  2009070100           1    3  2.20 -1.21  2.51  118.71     1
# 3  2009070100           1    4  2.35 -1.40  2.73  120.86     1
# 4  2009070100           1    5  2.53 -1.47  2.93  120.13     1

# %%
del df['date']

# %%
df.to_csv("../dataset/wind_forecast_edited.csv", index=False)

# %%
df1 = pd.read_pickle("../dataset/3p6.pkl", compression="zip")

# %%
df1.head()
# Out:
#        x     y     z    vx    vy   vz    px    py    pz  time  distance
# 0 -117.0  87.0 -33.0  0.46  0.02 -0.0  2.47 -2.39 -0.49   363     150.0
# 1 -113.0  87.0 -33.0  0.46  0.02  0.0  2.54 -2.25 -0.54   363     146.0
# 2 -109.0  87.0 -33.0  0.47  0.03  0.0  2.44 -2.00 -0.58   363     143.0
# 3 -105.0  87.0 -33.0  0.47  0.03  0.0  2.21 -1.68 -0.61   363     140.0
# 4 -101.0  87.0 -33.0  0.47  0.03  0.0  1.89 -1.36 -0.60   363     137.0

# %%
df1.shape
# Out:
# (60823200, 11)

# %%
filtered_df = df1[(df1['time']>=300) & (df1['time']<=305)]

# %%
filtered_df['px'].hist()
# Out:
# <Axes: >

# %%
filtered_df.to_pickle("../dataset/3p6-selected.pkl", compression='zip')

# %%
filtered_df.head()
# Out:
#              x     y     z    vx    vy    vz    px    py    pz  time  distance
# 1824696 -117.0  87.0 -33.0  0.48  0.02  0.04 -0.57 -0.11 -2.17   301     150.0
# 1824697 -113.0  87.0 -33.0  0.48  0.02  0.04 -0.50 -0.40 -2.10   301     146.0
# 1824698 -109.0  87.0 -33.0  0.48  0.02  0.04 -0.45 -0.58 -2.01   301     143.0
# 1824699 -105.0  87.0 -33.0  0.48  0.02  0.04 -0.42 -0.67 -1.91   301     140.0
# 1824700 -101.0  87.0 -33.0  0.48  0.02  0.05 -0.36 -0.69 -1.80   301     137.0

# %%
filtered_df.shape
# Out:
# (304116, 11)

# %%
filtered_df.drop(columns=['x','y','z'], inplace=True)
# Out:
# /tmp/ipykernel_1842308/1781166306.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.drop(columns=['x','y','z'], inplace=True)

# %%
filtered_df.head()
# Out:
#            vx    vy    vz    px    py    pz  time  distance
# 1824696  0.48  0.02  0.04 -0.57 -0.11 -2.17   301     150.0
# 1824697  0.48  0.02  0.04 -0.50 -0.40 -2.10   301     146.0
# 1824698  0.48  0.02  0.04 -0.45 -0.58 -2.01   301     143.0
# 1824699  0.48  0.02  0.04 -0.42 -0.67 -1.91   301     140.0
# 1824700  0.48  0.02  0.05 -0.36 -0.69 -1.80   301     137.0

# %%
filtered_df.to_pickle("../dataset/3p6-relative.pkl", compression='zip')
